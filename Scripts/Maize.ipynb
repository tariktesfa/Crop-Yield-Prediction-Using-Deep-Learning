# %%
import pandas as pd
import numpy as np

path = "drive/MyDrive/Capstone/"
crop_1 = "Barley"
crop_2 = "Maize"
crop_6 = "Sorghum"
crop_7 = "Teff"
crop_8 = "Wheat"

# %%
crop = crop_2
dfs = []

features = { "region": "Region", 
                "zone": "Zone", 
                "district": "District", 
                "production": "Production Of Condition in Kg",
                "area": "Area in Square meter", 
                "irrigated": 'Is Field Irrigated?',
                #"erosion": 'Is Field Prevented form Erosion',
                "seed": 'Seed / Seedling Type',
                "fertilizer" : 'Is Fertilizer Used?',
                "seed_qty": 'Quantity of indigenous seeds used',
                "fetilizer_type" : 'Type of fertilizer used if any?',
                "erosion_prevention" : 'Common way of prevention',
                "fertilizer_qty" : "Fertilizer Quantity",
                "damage": "Was crop damaged?",
                "previous": 'What was the previous state of the field?',
                #"damage_percent": 'Damage in Percent', 
                }

column_rename_dict = {}

column_rename_dict.update(dict.fromkeys(["DAMAGE" , "Was crop damaged ?", "Is there Damage?", "Any Damage?", "Any Damage", "Was crop dammaged"],
                             features["damage"]))

column_rename_dict.update(dict.fromkeys(['Used Irrigation?','Is field irrigated','Irrigation Used','Irrigation used?','IRRG'],
                             features["irrigated"]))

#column_rename_dict.update(dict.fromkeys(['Is the Soil Erosion', 'SERRO', 'Soil Erosion', 'Prevention for soil erosion?', 'Is Field Prevented form Erosion', ],
#                             features["erosion"]))

column_rename_dict.update(dict.fromkeys(['SEEDTYPE', 'Seed type', 'Seed Type', 'SEED TYPE',],
                             features["seed"]))

column_rename_dict.update(dict.fromkeys(['Is fertilizer used', 'Ferilizer', 'FERT', 'Fertilizer Used?', 'Fertilizer Used'],
                             features["fertilizer"]))

column_rename_dict.update(dict.fromkeys(['Weight of Indigenous seed', 'Weight of non-improved seed',  'Weight of Non-improved Seed', 'WTNISEED',],
                             features["seed_qty"]))

column_rename_dict.update(dict.fromkeys(['Fertilizer Type','FERTTYPE',],
                             features["fetilizer_type"]))

column_rename_dict.update(dict.fromkeys(['If field Prevented form Erosion, common way of prevention', 'MERRO', 'Measures taken to prevent Soil Erosion',],
                             features["erosion_prevention"]))

column_rename_dict.update(dict.fromkeys(['What was the previous state of the field ?', 'D26','What was the field used for?',],
                             features["previous"]))

start_year = 2010

for year in range(start_year, 2022):
  df_temp = pd.read_csv(f"{path}Clean_Meher_{year}_{crop}.csv")

  df_temp.rename(columns=column_rename_dict, inplace=True)

  dfs.append(df_temp)

# %%
columns = list(features.values())

for idx, df in enumerate(dfs):
  dfs[idx] = df[columns]

for df in dfs:
  print(df.shape)
# Out:
# (18480, 14)
# (37689, 14)
# (23774, 14)
# (47935, 14)
# (41914, 14)
# (37465, 14)
# (39529, 14)
# (33779, 14)
# (20708, 14)
# (22092, 14)
# (36167, 14)
# (32294, 14)

# %%
df = pd.concat(dfs)
df.shape
# Out:
# (391826, 14)

# %%
min_threshold, max_threshold = df[[features["production"]]].quantile([0.01, 0.99]).values[:, 0]
min_threshold, max_threshold
# Out:
# (5.562, 2387.9755)

# %%
df = df[(df[features["production"]] > min_threshold) & (df[features["production"]] < max_threshold)]

# %%
df_region = pd.get_dummies(df[features["region"]]).iloc[:, :-1]
df_zone = pd.get_dummies(df[features["zone"]]).iloc[:, :-1]
df_district = pd.get_dummies(df[features["district"]]).iloc[:, :-1]
df_damage = pd.get_dummies(df[features["damage"]]).iloc[:, :-1]
df_irrigated = pd.get_dummies(df[features["irrigated"]]).iloc[:, :-1]
#df_erosion = pd.get_dummies(df[features["erosion"]]).iloc[:, :-1]
df_erosion_prevention = pd.get_dummies(df[features["erosion_prevention"]]).iloc[:, :-1]
df_seed = pd.get_dummies(df[features["seed"]]).iloc[:, :-1]
df_fertilizer = pd.get_dummies(df[features["fertilizer"]]).iloc[:, :-1]
df_fetilizer_type = pd.get_dummies(df[features["fetilizer_type"]]).iloc[:, :-1]
df_previous = pd.get_dummies(df[features["previous"]]).iloc[:, :-1]

# %%
df = df.drop([features["region"], features["zone"], features["district"], features["damage"], features["irrigated"], features["seed"], features["fertilizer"], features["erosion_prevention"], features["fetilizer_type"], features["previous"]], axis = 1)

# %%
df_save = df.iloc[ : 1]

for col in df_save.columns:
    df_save[col].values[:] = 0

df_save
# Out:
#     Production Of Condition in Kg  Area in Square meter  \
# 15                            0.0                   0.0
#
#     Quantity of indigenous seeds used  Fertilizer Quantity
# 15                                0.0                  0.0

# %%
df = pd.concat([df, df_region, df_zone, df_district, df_damage, df_irrigated, df_erosion_prevention, df_seed, df_fertilizer, df_fetilizer_type, df_previous  ], axis = 1)

# %%
X = df.loc[:, df.columns != 'Production Of Condition in Kg']
y = df.loc[:, df.columns == "Production Of Condition in Kg"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

X_train.shape, X_test.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# ((268790, 89), (115196, 89))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import Input

model = Sequential()

# %%
input_layer = X_train.shape[1]
model.add(Input(shape=(input_layer,)))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = 1, kernel_initializer ="uniform"))
model.compile(loss='mean_squared_error', optimizer='adam',  metrics=['RootMeanSquaredError'])

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size = 500, epochs = 100)
# Out:
# Epoch 1/100
# 538/538 [==============================] - 5s 7ms/step - loss: 90147.3516 - root_mean_squared_error: 300.2455 - val_loss: 39891.6602 - val_root_mean_squared_error: 199.7290
# Epoch 2/100
# 538/538 [==============================] - 2s 4ms/step - loss: 39142.2852 - root_mean_squared_error: 197.8441 - val_loss: 38361.6484 - val_root_mean_squared_error: 195.8613
# Epoch 3/100
# 538/538 [==============================] - 2s 4ms/step - loss: 38133.5117 - root_mean_squared_error: 195.2780 - val_loss: 37412.3789 - val_root_mean_squared_error: 193.4228
# Epoch 4/100
# 538/538 [==============================] - 2s 4ms/step - loss: 37602.9297 - root_mean_squared_error: 193.9147 - val_loss: 37060.2305 - val_root_mean_squared_error: 192.5103
# Epoch 5/100
# 538/538 [==============================] - 2s 4ms/step - loss: 37159.2422 - root_mean_squared_error: 192.7673 - val_loss: 36641.4336 - val_root_mean_squared_error: 191.4195
# Epoch 6/100
# 538/538 [==============================] - 2s 4ms/step - loss: 36744.8320 - root_mean_squared_error: 191.6894 - val_loss: 36351.5664 - val_root_mean_squared_error: 190.6609
# Epoch 7/100
# 538/538 [==============================] - 2s 4ms/step - loss: 36405.6484 - root_mean_squared_error: 190.8026 - val_loss: 36074.6875 - val_root_mean_squared_error: 189.9334
# Epoch 8/100
# 538/538 [==============================] - 2s 4ms/step - loss: 36129.4727 - root_mean_squared_error: 190.0775 - val_loss: 35674.3008 - val_root_mean_squared_error: 188.8764
# Epoch 9/100
# 538/538 [==============================] - 2s 4ms/step - loss: 35949.7812 - root_mean_squared_error: 189.6043 - val_loss: 35734.1016 - val_root_mean_squared_error: 189.0347
# Epoch 10/100
# 538/538 [==============================] - 2s 4ms/step - loss: 35781.3750 - root_mean_squared_error: 189.1597 - val_loss: 35436.0430 - val_root_mean_squared_error: 188.2446
# Epoch 11/100
# 538/538 [==============================] - 2s 4ms/step - loss: 35616.2656 - root_mean_squared_error: 188.7227 - val_loss: 35592.2773 - val_root_mean_squared_error: 188.6591
# Epoch 12/100
# 538/538 [==============================] - 2s 4ms/step - loss: 35467.7773 - root_mean_squared_error: 188.3289 - val_loss: 35160.7500 - val_root_mean_squared_error: 187.5120
# Epoch 13/100
# 538/538 [==============================] - 2s 4ms/step - loss: 35311.4805 - root_mean_squared_error: 187.9135 - val_loss: 35061.0273 - val_root_mean_squared_error: 187.2459
# Epoch 14/100
# 538/538 [==============================] - 2s 4ms/step - loss: 35129.9531 - root_mean_squared_error: 187.4299 - val_loss: 34909.2695 - val_root_mean_squared_error: 186.8402
# Epoch 15/100
# 538/538 [==============================] - 2s 4ms/step - loss: 34489.9453 - root_mean_squared_error: 185.7147 - val_loss: 34072.5898 - val_root_mean_squared_error: 184.5876
# Epoch 16/100
# 538/538 [==============================] - 2s 4ms/step - loss: 33927.2383 - root_mean_squared_error: 184.1935 - val_loss: 33521.0195 - val_root_mean_squared_error: 183.0875
# Epoch 17/100
# 538/538 [==============================] - 2s 4ms/step - loss: 33619.5000 - root_mean_squared_error: 183.3562 - val_loss: 33274.4570 - val_root_mean_squared_error: 182.4129
# Epoch 18/100
# 538/538 [==============================] - 2s 4ms/step - loss: 33431.4297 - root_mean_squared_error: 182.8426 - val_loss: 33238.8672 - val_root_mean_squared_error: 182.3153
# Epoch 19/100
# 538/538 [==============================] - 2s 4ms/step - loss: 33166.0547 - root_mean_squared_error: 182.1155 - val_loss: 33369.1953 - val_root_mean_squared_error: 182.6724
# Epoch 20/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32993.0859 - root_mean_squared_error: 181.6400 - val_loss: 32934.1289 - val_root_mean_squared_error: 181.4776
# Epoch 21/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32806.0000 - root_mean_squared_error: 181.1243 - val_loss: 32978.4375 - val_root_mean_squared_error: 181.5997
# Epoch 22/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32629.3809 - root_mean_squared_error: 180.6360 - val_loss: 32797.2969 - val_root_mean_squared_error: 181.1002
# Epoch 23/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32445.0391 - root_mean_squared_error: 180.1251 - val_loss: 32583.0156 - val_root_mean_squared_error: 180.5077
# Epoch 24/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32372.8125 - root_mean_squared_error: 179.9245 - val_loss: 32546.9082 - val_root_mean_squared_error: 180.4076
# Epoch 25/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32213.8574 - root_mean_squared_error: 179.4822 - val_loss: 32199.1797 - val_root_mean_squared_error: 179.4413
# Epoch 26/100
# 538/538 [==============================] - 2s 4ms/step - loss: 32045.7793 - root_mean_squared_error: 179.0134 - val_loss: 32063.3535 - val_root_mean_squared_error: 179.0624
# Epoch 27/100
# 538/538 [==============================] - 3s 6ms/step - loss: 32000.4180 - root_mean_squared_error: 178.8866 - val_loss: 31915.0098 - val_root_mean_squared_error: 178.6477
# Epoch 28/100
# 538/538 [==============================] - 3s 5ms/step - loss: 31843.8848 - root_mean_squared_error: 178.4485 - val_loss: 31880.7832 - val_root_mean_squared_error: 178.5519
# Epoch 29/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31751.4297 - root_mean_squared_error: 178.1893 - val_loss: 32023.5078 - val_root_mean_squared_error: 178.9511
# Epoch 30/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31651.1289 - root_mean_squared_error: 177.9076 - val_loss: 31752.1426 - val_root_mean_squared_error: 178.1913
# Epoch 31/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31571.1816 - root_mean_squared_error: 177.6828 - val_loss: 31621.4570 - val_root_mean_squared_error: 177.8242
# Epoch 32/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31475.8184 - root_mean_squared_error: 177.4143 - val_loss: 31802.0195 - val_root_mean_squared_error: 178.3312
# Epoch 33/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31420.6445 - root_mean_squared_error: 177.2587 - val_loss: 31868.9805 - val_root_mean_squared_error: 178.5188
# Epoch 34/100
# 538/538 [==============================] - 3s 5ms/step - loss: 31362.2812 - root_mean_squared_error: 177.0940 - val_loss: 31636.0566 - val_root_mean_squared_error: 177.8653
# Epoch 35/100
# 538/538 [==============================] - 3s 5ms/step - loss: 31268.4199 - root_mean_squared_error: 176.8288 - val_loss: 31953.7793 - val_root_mean_squared_error: 178.7562
# Epoch 36/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31193.9766 - root_mean_squared_error: 176.6182 - val_loss: 31604.2480 - val_root_mean_squared_error: 177.7758
# Epoch 37/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31163.5938 - root_mean_squared_error: 176.5321 - val_loss: 31961.4727 - val_root_mean_squared_error: 178.7777
# Epoch 38/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31084.0703 - root_mean_squared_error: 176.3067 - val_loss: 31225.8105 - val_root_mean_squared_error: 176.7083
# Epoch 39/100
# 538/538 [==============================] - 2s 4ms/step - loss: 31074.3164 - root_mean_squared_error: 176.2791 - val_loss: 31365.7363 - val_root_mean_squared_error: 177.1037
# Epoch 40/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30977.1777 - root_mean_squared_error: 176.0033 - val_loss: 31318.5410 - val_root_mean_squared_error: 176.9705
# Epoch 41/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30982.4785 - root_mean_squared_error: 176.0184 - val_loss: 31298.0117 - val_root_mean_squared_error: 176.9124
# Epoch 42/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30946.1777 - root_mean_squared_error: 175.9153 - val_loss: 31322.9609 - val_root_mean_squared_error: 176.9829
# Epoch 43/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30845.6680 - root_mean_squared_error: 175.6293 - val_loss: 31631.1543 - val_root_mean_squared_error: 177.8515
# Epoch 44/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30825.9922 - root_mean_squared_error: 175.5733 - val_loss: 31348.4668 - val_root_mean_squared_error: 177.0550
# Epoch 45/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30808.7129 - root_mean_squared_error: 175.5241 - val_loss: 31561.4238 - val_root_mean_squared_error: 177.6553
# Epoch 46/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30688.5371 - root_mean_squared_error: 175.1814 - val_loss: 31406.6191 - val_root_mean_squared_error: 177.2191
# Epoch 47/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30709.1758 - root_mean_squared_error: 175.2403 - val_loss: 31605.4590 - val_root_mean_squared_error: 177.7792
# Epoch 48/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30601.8008 - root_mean_squared_error: 174.9337 - val_loss: 31222.3691 - val_root_mean_squared_error: 176.6985
# Epoch 49/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30578.9453 - root_mean_squared_error: 174.8684 - val_loss: 31281.1602 - val_root_mean_squared_error: 176.8648
# Epoch 50/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30553.8711 - root_mean_squared_error: 174.7967 - val_loss: 31115.1699 - val_root_mean_squared_error: 176.3949
# Epoch 51/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30572.3652 - root_mean_squared_error: 174.8495 - val_loss: 31104.0547 - val_root_mean_squared_error: 176.3634
# Epoch 52/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30531.9023 - root_mean_squared_error: 174.7338 - val_loss: 30993.6602 - val_root_mean_squared_error: 176.0502
# Epoch 53/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30386.5156 - root_mean_squared_error: 174.3173 - val_loss: 30959.9199 - val_root_mean_squared_error: 175.9543
# Epoch 54/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30460.8613 - root_mean_squared_error: 174.5304 - val_loss: 31655.8125 - val_root_mean_squared_error: 177.9208
# Epoch 55/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30458.5234 - root_mean_squared_error: 174.5237 - val_loss: 31089.8262 - val_root_mean_squared_error: 176.3231
# Epoch 56/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30447.1133 - root_mean_squared_error: 174.4910 - val_loss: 31133.7832 - val_root_mean_squared_error: 176.4477
# Epoch 57/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30370.9023 - root_mean_squared_error: 174.2725 - val_loss: 31179.5605 - val_root_mean_squared_error: 176.5773
# Epoch 58/100
# 538/538 [==============================] - 3s 5ms/step - loss: 30355.5918 - root_mean_squared_error: 174.2286 - val_loss: 31319.2012 - val_root_mean_squared_error: 176.9723
# Epoch 59/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30326.8672 - root_mean_squared_error: 174.1461 - val_loss: 30984.5098 - val_root_mean_squared_error: 176.0242
# Epoch 60/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30336.7246 - root_mean_squared_error: 174.1744 - val_loss: 30847.1562 - val_root_mean_squared_error: 175.6336
# Epoch 61/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30236.3125 - root_mean_squared_error: 173.8859 - val_loss: 30737.3477 - val_root_mean_squared_error: 175.3207
# Epoch 62/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30239.8809 - root_mean_squared_error: 173.8962 - val_loss: 30830.6191 - val_root_mean_squared_error: 175.5865
# Epoch 63/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30208.7188 - root_mean_squared_error: 173.8065 - val_loss: 30918.0254 - val_root_mean_squared_error: 175.8352
# Epoch 64/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30197.6914 - root_mean_squared_error: 173.7748 - val_loss: 31114.0820 - val_root_mean_squared_error: 176.3918
# Epoch 65/100
# 538/538 [==============================] - 2s 5ms/step - loss: 30152.3633 - root_mean_squared_error: 173.6444 - val_loss: 30802.2715 - val_root_mean_squared_error: 175.5058
# Epoch 66/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30169.8750 - root_mean_squared_error: 173.6948 - val_loss: 30846.9043 - val_root_mean_squared_error: 175.6329
# Epoch 67/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30121.5527 - root_mean_squared_error: 173.5556 - val_loss: 30708.4570 - val_root_mean_squared_error: 175.2383
# Epoch 68/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30116.2754 - root_mean_squared_error: 173.5404 - val_loss: 30735.9766 - val_root_mean_squared_error: 175.3168
# Epoch 69/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30077.7051 - root_mean_squared_error: 173.4292 - val_loss: 30596.1914 - val_root_mean_squared_error: 174.9177
# Epoch 70/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29982.2148 - root_mean_squared_error: 173.1537 - val_loss: 31162.8086 - val_root_mean_squared_error: 176.5299
# Epoch 71/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30015.6309 - root_mean_squared_error: 173.2502 - val_loss: 31156.8574 - val_root_mean_squared_error: 176.5130
# Epoch 72/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29956.0391 - root_mean_squared_error: 173.0781 - val_loss: 30669.1797 - val_root_mean_squared_error: 175.1262
# Epoch 73/100
# 538/538 [==============================] - 2s 4ms/step - loss: 30020.5176 - root_mean_squared_error: 173.2643 - val_loss: 30993.9316 - val_root_mean_squared_error: 176.0509
# Epoch 74/100
# 538/538 [==============================] - 2s 5ms/step - loss: 29891.8965 - root_mean_squared_error: 172.8927 - val_loss: 30837.3301 - val_root_mean_squared_error: 175.6056
# Epoch 75/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29873.2148 - root_mean_squared_error: 172.8387 - val_loss: 30639.9551 - val_root_mean_squared_error: 175.0427
# Epoch 76/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29937.9727 - root_mean_squared_error: 173.0259 - val_loss: 30651.9961 - val_root_mean_squared_error: 175.0771
# Epoch 77/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29858.9629 - root_mean_squared_error: 172.7975 - val_loss: 30622.8828 - val_root_mean_squared_error: 174.9940
# Epoch 78/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29848.2891 - root_mean_squared_error: 172.7666 - val_loss: 31148.8613 - val_root_mean_squared_error: 176.4904
# Epoch 79/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29826.0273 - root_mean_squared_error: 172.7021 - val_loss: 30555.8574 - val_root_mean_squared_error: 174.8023
# Epoch 80/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29831.1641 - root_mean_squared_error: 172.7170 - val_loss: 30905.2793 - val_root_mean_squared_error: 175.7990
# Epoch 81/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29840.3242 - root_mean_squared_error: 172.7435 - val_loss: 30687.8418 - val_root_mean_squared_error: 175.1795
# Epoch 82/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29832.7480 - root_mean_squared_error: 172.7216 - val_loss: 30531.1660 - val_root_mean_squared_error: 174.7317
# Epoch 83/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29787.5000 - root_mean_squared_error: 172.5906 - val_loss: 30616.8770 - val_root_mean_squared_error: 174.9768
# Epoch 84/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29749.3730 - root_mean_squared_error: 172.4801 - val_loss: 30546.4922 - val_root_mean_squared_error: 174.7755
# Epoch 85/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29756.6113 - root_mean_squared_error: 172.5011 - val_loss: 31444.2051 - val_root_mean_squared_error: 177.3251
# Epoch 86/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29699.1523 - root_mean_squared_error: 172.3344 - val_loss: 30819.2559 - val_root_mean_squared_error: 175.5541
# Epoch 87/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29661.1270 - root_mean_squared_error: 172.2241 - val_loss: 30691.1074 - val_root_mean_squared_error: 175.1888
# Epoch 88/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29656.0156 - root_mean_squared_error: 172.2092 - val_loss: 30549.1289 - val_root_mean_squared_error: 174.7831
# Epoch 89/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29663.8633 - root_mean_squared_error: 172.2320 - val_loss: 30412.4629 - val_root_mean_squared_error: 174.3917
# Epoch 90/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29563.2832 - root_mean_squared_error: 171.9398 - val_loss: 30451.5840 - val_root_mean_squared_error: 174.5038
# Epoch 91/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29648.1348 - root_mean_squared_error: 172.1863 - val_loss: 30836.2559 - val_root_mean_squared_error: 175.6026
# Epoch 92/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29590.3594 - root_mean_squared_error: 172.0185 - val_loss: 30507.7832 - val_root_mean_squared_error: 174.6648
# Epoch 93/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29583.0215 - root_mean_squared_error: 171.9972 - val_loss: 30595.0996 - val_root_mean_squared_error: 174.9146
# Epoch 94/100
# 538/538 [==============================] - 2s 5ms/step - loss: 29560.7949 - root_mean_squared_error: 171.9325 - val_loss: 30320.1953 - val_root_mean_squared_error: 174.1270
# Epoch 95/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29485.2559 - root_mean_squared_error: 171.7127 - val_loss: 30604.9531 - val_root_mean_squared_error: 174.9427
# Epoch 96/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29576.8789 - root_mean_squared_error: 171.9793 - val_loss: 30617.6602 - val_root_mean_squared_error: 174.9790
# Epoch 97/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29432.5664 - root_mean_squared_error: 171.5592 - val_loss: 30529.6582 - val_root_mean_squared_error: 174.7274
# Epoch 98/100
# 538/538 [==============================] - 2s 4ms/step - loss: 29461.2715 - root_mean_squared_error: 171.6429 - val_loss: 30877.1641 - val_root_mean_squared_error: 175.7190
# Epoch 99/100
# 538/538 [==============================] - 2s 5ms/step - loss: 29470.4395 - root_mean_squared_error: 171.6696 - val_loss: 30266.0996 - val_root_mean_squared_error: 173.9715
# Epoch 100/100
# 538/538 [==============================] - 2s 5ms/step - loss: 29404.3047 - root_mean_squared_error: 171.4768 - val_loss: 30881.3750 - val_root_mean_squared_error: 175.7310

# %%
def build_model(optimizer):
  model = Sequential()
  input_layer = X_train.shape[1] / 2
  model.add(Input(shape=(X_train.shape[1],)))
  model.add(Dense(units = input_layer, kernel_initializer = "uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = 1, kernel_initializer ="uniform"))
  model.compile(loss='mean_squared_error', optimizer=optimizer,  metrics=['RootMeanSquaredError'])
  return model

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense

classifier = KerasRegressor(build_fn = build_model)
parameters = {'batch_size': [10, 50],
              'epochs': [100],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'r2',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_

# %%
grid_search.best_estimator_.model.summary()

# %%
grid_search.best_estimator_.score(X_test, y_test)

# %%
model.summary()

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
from keras import backend as K

def coeff_determination(y_true, y_pred):

    y_true = K.constant(y_true)
    y_pred = K.constant(y_pred)
    
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
y_pred = model.predict(X_train)
coeff_determination(y_train.to_numpy(), y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.83421457>

# %%
y_pred = model.predict(X_test)
coeff_determination(y_test.to_numpy(), y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8261838>

# %%
import pickle

filename = path + crop + "_Model"

model.save(path + crop + "_Model.keras")

model

# %%
filename = path + crop + "_Scaler"

pickle.dump(sc, open(filename, "wb"))

sc
# Out:
# StandardScaler()

# %%
filename = path + crop + "_Df"

df_save = df_save.loc[:, df_save.columns != 'Production Of Condition in Kg']

pickle.dump(df_save, open(filename, "wb"))

df_save
# Out:
#     Area in Square meter  Quantity of indigenous seeds used  \
# 15                   0.0                                0.0
#
#     Fertilizer Quantity
# 15                  0.0

# %%
dfs = [df_region, df_zone, df_district, df_damage, df_irrigated, df_erosion_prevention, df_seed, df_fertilizer, df_fetilizer_type, df_previous]
labels = ["Region", "Zone", "District", "Damage", "Irrigated", "Erosion", "Seed", "Fertilizer", "Fertilizer_Type", "Previous"]

for idx in range(0, len(dfs)):
  df_selected = dfs[idx].iloc[ : 1]

  for col in df_selected.columns:
      df_selected[col].values[:] = 0

  filename = path + crop + "_" + labels[idx]
  pickle.dump(df_selected, open(filename, "wb"))

  print( labels[idx])
# Out:
# Region
# Zone
# District
# Damage
# Irrigated
# Erosion
# Seed
# Fertilizer
# Fertilizer_Type
# Previous
