# %%
import pandas as pd
import numpy as np

path = "drive/MyDrive/Capstone/"
crop_1 = "Barley"
crop_2 = "Maize"
crop_6 = "Sorghum"
crop_7 = "Teff"
crop_8 = "Wheat"

# %%
crop = crop_1
dfs = []

features = { "region": "Region", 
                "zone": "Zone", 
                "district": "District", 
                "production": "Production Of Condition in Kg",
                "area": "Area in Square meter", 
                "irrigated": 'Is Field Irrigated?',
                #"erosion": 'Is Field Prevented form Erosion',
                "seed": 'Seed / Seedling Type',
                "fertilizer" : 'Is Fertilizer Used?',
                "seed_qty": 'Quantity of indigenous seeds used',
                "fetilizer_type" : 'Type of fertilizer used if any?',
                "erosion_prevention" : 'Common way of prevention',
                "fertilizer_qty" : "Fertilizer Quantity",
                "damage": "Was crop damaged?",
                "previous": 'What was the previous state of the field?',
                #"damage_percent": 'Damage in Percent', 
                }

column_rename_dict = {}

column_rename_dict.update(dict.fromkeys(["DAMAGE" , "Was crop damaged ?", "Is there Damage?", "Any Damage?", "Any Damage", "Was crop dammaged"],
                             features["damage"]))

column_rename_dict.update(dict.fromkeys(['Used Irrigation?','Is field irrigated','Irrigation Used','Irrigation used?','IRRG'],
                             features["irrigated"]))

#column_rename_dict.update(dict.fromkeys(['Is the Soil Erosion', 'SERRO', 'Soil Erosion', 'Prevention for soil erosion?', 'Is Field Prevented form Erosion', ],
#                             features["erosion"]))

column_rename_dict.update(dict.fromkeys(['SEEDTYPE', 'Seed type', 'Seed Type', 'SEED TYPE',],
                             features["seed"]))

column_rename_dict.update(dict.fromkeys(['Is fertilizer used', 'Ferilizer', 'FERT', 'Fertilizer Used?', 'Fertilizer Used'],
                             features["fertilizer"]))

column_rename_dict.update(dict.fromkeys(['Weight of Indigenous seed', 'Weight of non-improved seed',  'Weight of Non-improved Seed', 'WTNISEED',],
                             features["seed_qty"]))

column_rename_dict.update(dict.fromkeys(['Fertilizer Type','FERTTYPE',],
                             features["fetilizer_type"]))

column_rename_dict.update(dict.fromkeys(['If field Prevented form Erosion, common way of prevention', 'MERRO', 'Measures taken to prevent Soil Erosion',],
                             features["erosion_prevention"]))

column_rename_dict.update(dict.fromkeys(['What was the previous state of the field ?', 'D26','What was the field used for?',],
                             features["previous"]))

start_year = 2010

for year in range(start_year, 2022):
  df_temp = pd.read_csv(f"{path}Clean_Meher_{year}_{crop}.csv")

  df_temp.rename(columns=column_rename_dict, inplace=True)

  dfs.append(df_temp)

# %%
columns = list(features.values())

for idx, df in enumerate(dfs):
  dfs[idx] = df[columns]

for df in dfs:
  print(df.shape)
# Out:
# (11524, 14)
# (17982, 14)
# (10948, 14)
# (18788, 14)
# (18973, 14)
# (17124, 14)
# (16168, 14)
# (14765, 14)
# (7333, 14)
# (8522, 14)
# (12231, 14)
# (12141, 14)

# %%
df = pd.concat(dfs)
df.shape
# Out:
# (166499, 14)

# %%
min_threshold, max_threshold = df[[features["production"]]].quantile([0.01, 0.99]).values[:, 0]
min_threshold, max_threshold
# Out:
# (4.786, 1393.0106599999976)

# %%
df = df[(df[features["production"]] > min_threshold) & (df[features["production"]] < max_threshold)]

# %%
df_region = pd.get_dummies(df[features["region"]]).iloc[:, :-1]
df_zone = pd.get_dummies(df[features["zone"]]).iloc[:, :-1]
df_district = pd.get_dummies(df[features["district"]]).iloc[:, :-1]
df_damage = pd.get_dummies(df[features["damage"]]).iloc[:, :-1]
df_irrigated = pd.get_dummies(df[features["irrigated"]]).iloc[:, :-1]
#df_erosion = pd.get_dummies(df[features["erosion"]]).iloc[:, :-1]
df_erosion_prevention = pd.get_dummies(df[features["erosion_prevention"]]).iloc[:, :-1]
df_seed = pd.get_dummies(df[features["seed"]]).iloc[:, :-1]
df_fertilizer = pd.get_dummies(df[features["fertilizer"]]).iloc[:, :-1]
df_fetilizer_type = pd.get_dummies(df[features["fetilizer_type"]]).iloc[:, :-1]
df_previous = pd.get_dummies(df[features["previous"]]).iloc[:, :-1]

# %%
df = df.drop([features["region"], features["zone"], features["district"], features["damage"], features["irrigated"], features["seed"], features["fertilizer"], features["erosion_prevention"], features["fetilizer_type"], features["previous"]], axis = 1)

# %%
df_save = df.iloc[ : 1]

for col in df_save.columns:
    df_save[col].values[:] = 0

df_save
# Out:
#    Production Of Condition in Kg  Area in Square meter  \
# 0                            0.0                   0.0
#
#    Quantity of indigenous seeds used  Fertilizer Quantity
# 0                                0.0                  0.0

# %%
df = pd.concat([df, df_region, df_zone, df_district, df_damage, df_irrigated, df_erosion_prevention, df_seed, df_fertilizer, df_fetilizer_type, df_previous  ], axis = 1)

# %%
X = df.loc[:, df.columns != 'Production Of Condition in Kg']
y = df.loc[:, df.columns == "Production Of Condition in Kg"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

X_train.shape, X_test.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# ((114217, 86), (48951, 86))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import Input

model = Sequential()

# %%
input_layer = X_train.shape[1]
model.add(Input(shape=(input_layer,)))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = 1, kernel_initializer ="uniform"))
model.compile(loss='mean_squared_error', optimizer='adam',  metrics=['RootMeanSquaredError'])

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size = 500, epochs = 65)
# Out:
# Epoch 1/65
# 229/229 [==============================] - 2s 5ms/step - loss: 48851.3789 - root_mean_squared_error: 221.0235 - val_loss: 18206.2090 - val_root_mean_squared_error: 134.9304
# Epoch 2/65
# 229/229 [==============================] - 1s 4ms/step - loss: 15470.6074 - root_mean_squared_error: 124.3809 - val_loss: 14966.5498 - val_root_mean_squared_error: 122.3379
# Epoch 3/65
# 229/229 [==============================] - 1s 4ms/step - loss: 14245.2725 - root_mean_squared_error: 119.3536 - val_loss: 14332.2148 - val_root_mean_squared_error: 119.7172
# Epoch 4/65
# 229/229 [==============================] - 1s 5ms/step - loss: 13661.0693 - root_mean_squared_error: 116.8806 - val_loss: 13697.6006 - val_root_mean_squared_error: 117.0368
# Epoch 5/65
# 229/229 [==============================] - 1s 4ms/step - loss: 13091.4258 - root_mean_squared_error: 114.4178 - val_loss: 13176.5537 - val_root_mean_squared_error: 114.7892
# Epoch 6/65
# 229/229 [==============================] - 1s 4ms/step - loss: 12662.7568 - root_mean_squared_error: 112.5289 - val_loss: 12927.7256 - val_root_mean_squared_error: 113.7002
# Epoch 7/65
# 229/229 [==============================] - 1s 5ms/step - loss: 12366.5840 - root_mean_squared_error: 111.2051 - val_loss: 12540.7363 - val_root_mean_squared_error: 111.9854
# Epoch 8/65
# 229/229 [==============================] - 1s 4ms/step - loss: 12120.0029 - root_mean_squared_error: 110.0909 - val_loss: 12369.5078 - val_root_mean_squared_error: 111.2183
# Epoch 9/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11943.8691 - root_mean_squared_error: 109.2880 - val_loss: 12219.0107 - val_root_mean_squared_error: 110.5396
# Epoch 10/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11768.9287 - root_mean_squared_error: 108.4847 - val_loss: 12114.2490 - val_root_mean_squared_error: 110.0648
# Epoch 11/65
# 229/229 [==============================] - 1s 5ms/step - loss: 11634.2539 - root_mean_squared_error: 107.8622 - val_loss: 11998.8291 - val_root_mean_squared_error: 109.5392
# Epoch 12/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11523.9795 - root_mean_squared_error: 107.3498 - val_loss: 11961.2041 - val_root_mean_squared_error: 109.3673
# Epoch 13/65
# 229/229 [==============================] - 1s 5ms/step - loss: 11454.0312 - root_mean_squared_error: 107.0235 - val_loss: 11897.4297 - val_root_mean_squared_error: 109.0753
# Epoch 14/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11351.5459 - root_mean_squared_error: 106.5436 - val_loss: 11887.4336 - val_root_mean_squared_error: 109.0295
# Epoch 15/65
# 229/229 [==============================] - 1s 5ms/step - loss: 11265.9756 - root_mean_squared_error: 106.1413 - val_loss: 11795.6113 - val_root_mean_squared_error: 108.6076
# Epoch 16/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11221.1201 - root_mean_squared_error: 105.9298 - val_loss: 11741.0352 - val_root_mean_squared_error: 108.3561
# Epoch 17/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11127.2871 - root_mean_squared_error: 105.4860 - val_loss: 11677.2168 - val_root_mean_squared_error: 108.0612
# Epoch 18/65
# 229/229 [==============================] - 1s 4ms/step - loss: 11087.7363 - root_mean_squared_error: 105.2983 - val_loss: 11681.8994 - val_root_mean_squared_error: 108.0828
# Epoch 19/65
# 229/229 [==============================] - 1s 5ms/step - loss: 11052.1904 - root_mean_squared_error: 105.1294 - val_loss: 11724.8262 - val_root_mean_squared_error: 108.2812
# Epoch 20/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10993.2754 - root_mean_squared_error: 104.8488 - val_loss: 11641.8145 - val_root_mean_squared_error: 107.8972
# Epoch 21/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10945.1514 - root_mean_squared_error: 104.6191 - val_loss: 11701.2920 - val_root_mean_squared_error: 108.1725
# Epoch 22/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10926.2305 - root_mean_squared_error: 104.5286 - val_loss: 11486.3066 - val_root_mean_squared_error: 107.1742
# Epoch 23/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10871.2539 - root_mean_squared_error: 104.2653 - val_loss: 11693.0000 - val_root_mean_squared_error: 108.1342
# Epoch 24/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10839.3994 - root_mean_squared_error: 104.1124 - val_loss: 11897.3350 - val_root_mean_squared_error: 109.0749
# Epoch 25/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10835.7949 - root_mean_squared_error: 104.0951 - val_loss: 11571.5986 - val_root_mean_squared_error: 107.5714
# Epoch 26/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10767.1562 - root_mean_squared_error: 103.7649 - val_loss: 11469.9434 - val_root_mean_squared_error: 107.0978
# Epoch 27/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10737.9307 - root_mean_squared_error: 103.6240 - val_loss: 11439.9072 - val_root_mean_squared_error: 106.9575
# Epoch 28/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10683.3555 - root_mean_squared_error: 103.3603 - val_loss: 11408.3613 - val_root_mean_squared_error: 106.8099
# Epoch 29/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10667.4316 - root_mean_squared_error: 103.2833 - val_loss: 11427.1289 - val_root_mean_squared_error: 106.8978
# Epoch 30/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10635.7129 - root_mean_squared_error: 103.1296 - val_loss: 11431.3486 - val_root_mean_squared_error: 106.9175
# Epoch 31/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10612.3301 - root_mean_squared_error: 103.0162 - val_loss: 11481.9395 - val_root_mean_squared_error: 107.1538
# Epoch 32/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10577.8701 - root_mean_squared_error: 102.8488 - val_loss: 11410.4775 - val_root_mean_squared_error: 106.8198
# Epoch 33/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10576.1211 - root_mean_squared_error: 102.8403 - val_loss: 11426.0273 - val_root_mean_squared_error: 106.8926
# Epoch 34/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10532.1396 - root_mean_squared_error: 102.6262 - val_loss: 11527.8262 - val_root_mean_squared_error: 107.3677
# Epoch 35/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10530.4600 - root_mean_squared_error: 102.6180 - val_loss: 11409.5586 - val_root_mean_squared_error: 106.8155
# Epoch 36/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10497.2812 - root_mean_squared_error: 102.4562 - val_loss: 11372.6104 - val_root_mean_squared_error: 106.6424
# Epoch 37/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10472.2920 - root_mean_squared_error: 102.3342 - val_loss: 11370.0928 - val_root_mean_squared_error: 106.6306
# Epoch 38/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10448.5840 - root_mean_squared_error: 102.2183 - val_loss: 11536.5752 - val_root_mean_squared_error: 107.4084
# Epoch 39/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10422.6494 - root_mean_squared_error: 102.0914 - val_loss: 11341.0752 - val_root_mean_squared_error: 106.4945
# Epoch 40/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10393.7109 - root_mean_squared_error: 101.9496 - val_loss: 11400.6738 - val_root_mean_squared_error: 106.7739
# Epoch 41/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10389.3027 - root_mean_squared_error: 101.9279 - val_loss: 11287.0479 - val_root_mean_squared_error: 106.2405
# Epoch 42/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10361.3291 - root_mean_squared_error: 101.7906 - val_loss: 11356.2832 - val_root_mean_squared_error: 106.5659
# Epoch 43/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10356.8066 - root_mean_squared_error: 101.7684 - val_loss: 11297.8506 - val_root_mean_squared_error: 106.2914
# Epoch 44/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10327.8438 - root_mean_squared_error: 101.6260 - val_loss: 11355.7578 - val_root_mean_squared_error: 106.5634
# Epoch 45/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10348.2998 - root_mean_squared_error: 101.7266 - val_loss: 11485.9424 - val_root_mean_squared_error: 107.1725
# Epoch 46/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10308.1816 - root_mean_squared_error: 101.5292 - val_loss: 11352.4268 - val_root_mean_squared_error: 106.5478
# Epoch 47/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10275.0420 - root_mean_squared_error: 101.3659 - val_loss: 11275.3525 - val_root_mean_squared_error: 106.1855
# Epoch 48/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10269.4297 - root_mean_squared_error: 101.3382 - val_loss: 11300.0391 - val_root_mean_squared_error: 106.3016
# Epoch 49/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10276.3369 - root_mean_squared_error: 101.3723 - val_loss: 11333.9150 - val_root_mean_squared_error: 106.4609
# Epoch 50/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10244.9941 - root_mean_squared_error: 101.2176 - val_loss: 11294.3779 - val_root_mean_squared_error: 106.2750
# Epoch 51/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10219.8652 - root_mean_squared_error: 101.0933 - val_loss: 11172.9443 - val_root_mean_squared_error: 105.7021
# Epoch 52/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10201.2754 - root_mean_squared_error: 101.0014 - val_loss: 11540.7500 - val_root_mean_squared_error: 107.4279
# Epoch 53/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10207.5488 - root_mean_squared_error: 101.0324 - val_loss: 11396.5352 - val_root_mean_squared_error: 106.7546
# Epoch 54/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10229.2910 - root_mean_squared_error: 101.1400 - val_loss: 11331.9014 - val_root_mean_squared_error: 106.4514
# Epoch 55/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10185.4424 - root_mean_squared_error: 100.9230 - val_loss: 11331.7666 - val_root_mean_squared_error: 106.4508
# Epoch 56/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10153.5996 - root_mean_squared_error: 100.7651 - val_loss: 11390.1543 - val_root_mean_squared_error: 106.7247
# Epoch 57/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10183.8271 - root_mean_squared_error: 100.9149 - val_loss: 11297.0889 - val_root_mean_squared_error: 106.2878
# Epoch 58/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10163.5967 - root_mean_squared_error: 100.8147 - val_loss: 11291.5947 - val_root_mean_squared_error: 106.2619
# Epoch 59/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10155.4316 - root_mean_squared_error: 100.7742 - val_loss: 11354.0293 - val_root_mean_squared_error: 106.5553
# Epoch 60/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10120.8340 - root_mean_squared_error: 100.6024 - val_loss: 11240.5615 - val_root_mean_squared_error: 106.0215
# Epoch 61/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10089.8320 - root_mean_squared_error: 100.4482 - val_loss: 11207.7627 - val_root_mean_squared_error: 105.8667
# Epoch 62/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10136.2529 - root_mean_squared_error: 100.6790 - val_loss: 11512.4062 - val_root_mean_squared_error: 107.2959
# Epoch 63/65
# 229/229 [==============================] - 1s 5ms/step - loss: 10076.5059 - root_mean_squared_error: 100.3818 - val_loss: 11236.7295 - val_root_mean_squared_error: 106.0034
# Epoch 64/65
# 229/229 [==============================] - 1s 4ms/step - loss: 10078.7891 - root_mean_squared_error: 100.3932 - val_loss: 11259.0811 - val_root_mean_squared_error: 106.1088
# Epoch 65/65
# 229/229 [==============================] - 1s 6ms/step - loss: 10061.3340 - root_mean_squared_error: 100.3062 - val_loss: 11214.3926 - val_root_mean_squared_error: 105.8980

# %%
def build_model(optimizer):
  model = Sequential()
  input_layer = X_train.shape[1] / 2
  model.add(Input(shape=(X_train.shape[1],)))
  model.add(Dense(units = input_layer, kernel_initializer = "uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = 1, kernel_initializer ="uniform"))
  model.compile(loss='mean_squared_error', optimizer=optimizer,  metrics=['RootMeanSquaredError'])
  return model

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense

classifier = KerasRegressor(build_fn = build_model)
parameters = {'batch_size': [10, 50],
              'epochs': [100],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'r2',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_

# %%
grid_search.best_estimator_.model.summary()

# %%
grid_search.best_estimator_.score(X_test, y_test)

# %%
model.summary()

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
from keras import backend as K

def coeff_determination(y_true, y_pred):

    y_true = K.constant(y_true)
    y_pred = K.constant(y_pred)
    
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
y_pred = model.predict(X_train)
coeff_determination(y_train.to_numpy(), y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8223307>

# %%
y_pred = model.predict(X_test)
coeff_determination(y_test.to_numpy(), y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8027084>

# %%
import pickle

filename = path + crop + "_Model"

pickle.dump(model, open(filename, "wb"))

model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7dd18b70b426> in <module>()
#       3 filename = path + crop + "_Model"
#       4
# ----> 5 pickle.dump(model, open(filename, "wb"))
#       6
#       7 model
#
# NameError: name 'model' is not defined

# %%
filename = path + crop + "_Scaler"

pickle.dump(sc, open(filename, "wb"))

sc
# Out:
# StandardScaler()

# %%
filename = path + crop + "_Df"

df_save = df_save.loc[:, df_save.columns != 'Production Of Condition in Kg']

pickle.dump(df_save, open(filename, "wb"))

df_save
# Out:
#    Area in Square meter  Quantity of indigenous seeds used  \
# 0                   0.0                                0.0
#
#    Fertilizer Quantity
# 0                  0.0

# %%
dfs = [df_region, df_zone, df_district, df_damage, df_irrigated, df_erosion_prevention, df_seed, df_fertilizer, df_fetilizer_type, df_previous]
labels = ["Region", "Zone", "District", "Damage", "Irrigated", "Erosion", "Seed", "Fertilizer", "Fertilizer_Type", "Previous"]

for idx in range(0, len(dfs)):
  df_selected = dfs[idx].iloc[ : 1]

  for col in df_selected.columns:
      df_selected[col].values[:] = 0

  filename = path + crop + "_" + labels[idx]
  pickle.dump(df_selected, open(filename, "wb"))

  print( labels[idx])
# Out:
# Region
# Zone
# District
# Damage
# Irrigated
# Erosion
# Seed
# Fertilizer
# Fertilizer_Type
# Previous
