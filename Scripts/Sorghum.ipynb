# %%
import pandas as pd
import numpy as np

path = "drive/MyDrive/Capstone/"
crop_1 = "Barley"
crop_2 = "Maize"
crop_6 = "Sorghum"
crop_7 = "Teff"
crop_8 = "Wheat"

# %%
crop = crop_6
dfs = []

features = { "region": "Region", 
                "zone": "Zone", 
                "district": "District", 
                "production": "Production Of Condition in Kg",
                "area": "Area in Square meter", 
                "irrigated": 'Is Field Irrigated?',
                #"erosion": 'Is Field Prevented form Erosion',
                "seed": 'Seed / Seedling Type',
                "fertilizer" : 'Is Fertilizer Used?',
                "seed_qty": 'Quantity of indigenous seeds used',
                "fetilizer_type" : 'Type of fertilizer used if any?',
                "erosion_prevention" : 'Common way of prevention',
                "fertilizer_qty" : "Fertilizer Quantity",
                "damage": "Was crop damaged?",
                "previous": 'What was the previous state of the field?',
                #"damage_percent": 'Damage in Percent', 
                }

column_rename_dict = {}

column_rename_dict.update(dict.fromkeys(["DAMAGE" , "Was crop damaged ?", "Is there Damage?", "Any Damage?", "Any Damage", "Was crop dammaged"],
                             features["damage"]))

column_rename_dict.update(dict.fromkeys(['Used Irrigation?','Is field irrigated','Irrigation Used','Irrigation used?','IRRG'],
                             features["irrigated"]))

#column_rename_dict.update(dict.fromkeys(['Is the Soil Erosion', 'SERRO', 'Soil Erosion', 'Prevention for soil erosion?', 'Is Field Prevented form Erosion', ],
#                             features["erosion"]))

column_rename_dict.update(dict.fromkeys(['SEEDTYPE', 'Seed type', 'Seed Type', 'SEED TYPE',],
                             features["seed"]))

column_rename_dict.update(dict.fromkeys(['Is fertilizer used', 'Ferilizer', 'FERT', 'Fertilizer Used?', 'Fertilizer Used'],
                             features["fertilizer"]))

column_rename_dict.update(dict.fromkeys(['Weight of Indigenous seed', 'Weight of non-improved seed',  'Weight of Non-improved Seed', 'WTNISEED',],
                             features["seed_qty"]))

column_rename_dict.update(dict.fromkeys(['Fertilizer Type','FERTTYPE',],
                             features["fetilizer_type"]))

column_rename_dict.update(dict.fromkeys(['If field Prevented form Erosion, common way of prevention', 'MERRO', 'Measures taken to prevent Soil Erosion',],
                             features["erosion_prevention"]))

column_rename_dict.update(dict.fromkeys(['What was the previous state of the field ?', 'D26','What was the field used for?',],
                             features["previous"]))

start_year = 2010

for year in range(start_year, 2022):
  df_temp = pd.read_csv(f"{path}Clean_Meher_{year}_{crop}.csv")

  df_temp.rename(columns=column_rename_dict, inplace=True)

  dfs.append(df_temp)

# %%
columns = list(features.values())

for idx, df in enumerate(dfs):
  dfs[idx] = df[columns]

for df in dfs:
  print(df.shape)
# Out:
# (13848, 14)
# (27414, 14)
# (16807, 14)
# (28230, 14)
# (26069, 14)
# (27208, 14)
# (24880, 14)
# (21062, 14)
# (10850, 14)
# (12131, 14)
# (17559, 14)
# (15862, 14)

# %%
df = pd.concat(dfs)
df.shape
# Out:
# (241920, 14)

# %%
min_threshold, max_threshold = df[[features["production"]]].quantile([0.01, 0.99]).values[:, 0]
min_threshold, max_threshold
# Out:
# (5.18019, 1967.53903)

# %%
df = df[(df[features["production"]] > min_threshold) & (df[features["production"]] < max_threshold)]

# %%
df_region = pd.get_dummies(df[features["region"]]).iloc[:, :-1]
df_zone = pd.get_dummies(df[features["zone"]]).iloc[:, :-1]
df_district = pd.get_dummies(df[features["district"]]).iloc[:, :-1]
df_damage = pd.get_dummies(df[features["damage"]]).iloc[:, :-1]
df_irrigated = pd.get_dummies(df[features["irrigated"]]).iloc[:, :-1]
#df_erosion = pd.get_dummies(df[features["erosion"]]).iloc[:, :-1]
df_erosion_prevention = pd.get_dummies(df[features["erosion_prevention"]]).iloc[:, :-1]
df_seed = pd.get_dummies(df[features["seed"]]).iloc[:, :-1]
df_fertilizer = pd.get_dummies(df[features["fertilizer"]]).iloc[:, :-1]
df_fetilizer_type = pd.get_dummies(df[features["fetilizer_type"]]).iloc[:, :-1]
df_previous = pd.get_dummies(df[features["previous"]]).iloc[:, :-1]

# %%
df = df.drop([features["region"], features["zone"], features["district"], features["damage"], features["irrigated"], features["seed"], features["fertilizer"], features["erosion_prevention"], features["fetilizer_type"], features["previous"]], axis = 1)

# %%
df_save = df.iloc[ : 1]

for col in df_save.columns:
    df_save[col].values[:] = 0

df_save
# Out:
#    Production Of Condition in Kg  Area in Square meter  \
# 0                            0.0                   0.0
#
#    Quantity of indigenous seeds used  Fertilizer Quantity
# 0                                0.0                  0.0

# %%
df = pd.concat([df, df_region, df_zone, df_district, df_damage, df_irrigated, df_erosion_prevention, df_seed, df_fertilizer, df_fetilizer_type, df_previous  ], axis = 1)

# %%
X = df.loc[:, df.columns != 'Production Of Condition in Kg']
y = df.loc[:, df.columns == "Production Of Condition in Kg"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

X_train.shape, X_test.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# ((165956, 86), (71124, 86))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import Input

model = Sequential()

# %%
input_layer = X_train.shape[1]
model.add(Input(shape=(input_layer,)))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = input_layer / 2, kernel_initializer="uniform", activation = "relu"))
model.add(Dense(units = 1, kernel_initializer ="uniform"))
model.compile(loss='mean_squared_error', optimizer='adam',  metrics=['RootMeanSquaredError'])

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size = 200, epochs = 100)
# Out:
# Epoch 1/100
# 830/830 [==============================] - 8s 8ms/step - loss: 64027.3594 - root_mean_squared_error: 253.0363 - val_loss: 37954.2773 - val_root_mean_squared_error: 194.8186
# Epoch 2/100
# 830/830 [==============================] - 4s 5ms/step - loss: 36503.8477 - root_mean_squared_error: 191.0598 - val_loss: 36463.8164 - val_root_mean_squared_error: 190.9550
# Epoch 3/100
# 830/830 [==============================] - 3s 3ms/step - loss: 35265.0469 - root_mean_squared_error: 187.7899 - val_loss: 35249.6836 - val_root_mean_squared_error: 187.7490
# Epoch 4/100
# 830/830 [==============================] - 3s 4ms/step - loss: 34601.7578 - root_mean_squared_error: 186.0155 - val_loss: 34916.3164 - val_root_mean_squared_error: 186.8591
# Epoch 5/100
# 830/830 [==============================] - 3s 4ms/step - loss: 34109.4492 - root_mean_squared_error: 184.6874 - val_loss: 34416.0508 - val_root_mean_squared_error: 185.5156
# Epoch 6/100
# 830/830 [==============================] - 3s 4ms/step - loss: 33766.1016 - root_mean_squared_error: 183.7556 - val_loss: 34603.7734 - val_root_mean_squared_error: 186.0209
# Epoch 7/100
# 830/830 [==============================] - 3s 4ms/step - loss: 33448.7656 - root_mean_squared_error: 182.8900 - val_loss: 33947.0586 - val_root_mean_squared_error: 184.2473
# Epoch 8/100
# 830/830 [==============================] - 3s 4ms/step - loss: 33249.4961 - root_mean_squared_error: 182.3444 - val_loss: 33792.4883 - val_root_mean_squared_error: 183.8273
# Epoch 9/100
# 830/830 [==============================] - 3s 4ms/step - loss: 33130.5195 - root_mean_squared_error: 182.0179 - val_loss: 33656.2930 - val_root_mean_squared_error: 183.4565
# Epoch 10/100
# 830/830 [==============================] - 3s 4ms/step - loss: 32994.2812 - root_mean_squared_error: 181.6433 - val_loss: 33618.5781 - val_root_mean_squared_error: 183.3537
# Epoch 11/100
# 830/830 [==============================] - 3s 3ms/step - loss: 32850.5938 - root_mean_squared_error: 181.2473 - val_loss: 33616.7812 - val_root_mean_squared_error: 183.3488
# Epoch 12/100
# 830/830 [==============================] - 3s 4ms/step - loss: 32636.6035 - root_mean_squared_error: 180.6560 - val_loss: 33535.6953 - val_root_mean_squared_error: 183.1275
# Epoch 13/100
# 830/830 [==============================] - 3s 4ms/step - loss: 32213.0449 - root_mean_squared_error: 179.4799 - val_loss: 32855.2852 - val_root_mean_squared_error: 181.2603
# Epoch 14/100
# 830/830 [==============================] - 3s 4ms/step - loss: 31875.8926 - root_mean_squared_error: 178.5382 - val_loss: 32511.9531 - val_root_mean_squared_error: 180.3107
# Epoch 15/100
# 830/830 [==============================] - 3s 3ms/step - loss: 31603.9336 - root_mean_squared_error: 177.7749 - val_loss: 32372.0391 - val_root_mean_squared_error: 179.9223
# Epoch 16/100
# 830/830 [==============================] - 3s 4ms/step - loss: 31379.6523 - root_mean_squared_error: 177.1430 - val_loss: 32813.1094 - val_root_mean_squared_error: 181.1439
# Epoch 17/100
# 830/830 [==============================] - 3s 4ms/step - loss: 31246.4199 - root_mean_squared_error: 176.7666 - val_loss: 32146.3164 - val_root_mean_squared_error: 179.2939
# Epoch 18/100
# 830/830 [==============================] - 3s 4ms/step - loss: 31115.9395 - root_mean_squared_error: 176.3971 - val_loss: 32119.7188 - val_root_mean_squared_error: 179.2198
# Epoch 19/100
# 830/830 [==============================] - 3s 3ms/step - loss: 30980.1211 - root_mean_squared_error: 176.0117 - val_loss: 32059.8711 - val_root_mean_squared_error: 179.0527
# Epoch 20/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30913.3613 - root_mean_squared_error: 175.8220 - val_loss: 31896.4902 - val_root_mean_squared_error: 178.5959
# Epoch 21/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30773.7129 - root_mean_squared_error: 175.4244 - val_loss: 32181.9863 - val_root_mean_squared_error: 179.3934
# Epoch 22/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30731.3926 - root_mean_squared_error: 175.3037 - val_loss: 31759.5020 - val_root_mean_squared_error: 178.2120
# Epoch 23/100
# 830/830 [==============================] - 3s 3ms/step - loss: 30584.7598 - root_mean_squared_error: 174.8850 - val_loss: 31545.5391 - val_root_mean_squared_error: 177.6106
# Epoch 24/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30440.4414 - root_mean_squared_error: 174.4719 - val_loss: 31720.9316 - val_root_mean_squared_error: 178.1037
# Epoch 25/100
# 830/830 [==============================] - 3s 3ms/step - loss: 30495.3359 - root_mean_squared_error: 174.6291 - val_loss: 31490.8145 - val_root_mean_squared_error: 177.4565
# Epoch 26/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30385.5781 - root_mean_squared_error: 174.3146 - val_loss: 31476.0293 - val_root_mean_squared_error: 177.4149
# Epoch 27/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30258.5078 - root_mean_squared_error: 173.9497 - val_loss: 31717.2500 - val_root_mean_squared_error: 178.0934
# Epoch 28/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30216.9688 - root_mean_squared_error: 173.8303 - val_loss: 31983.2891 - val_root_mean_squared_error: 178.8387
# Epoch 29/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30171.3418 - root_mean_squared_error: 173.6990 - val_loss: 31568.6426 - val_root_mean_squared_error: 177.6757
# Epoch 30/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30118.2812 - root_mean_squared_error: 173.5462 - val_loss: 31512.7207 - val_root_mean_squared_error: 177.5182
# Epoch 31/100
# 830/830 [==============================] - 3s 4ms/step - loss: 30045.5547 - root_mean_squared_error: 173.3365 - val_loss: 31503.5918 - val_root_mean_squared_error: 177.4925
# Epoch 32/100
# 830/830 [==============================] - 4s 5ms/step - loss: 30032.1582 - root_mean_squared_error: 173.2979 - val_loss: 31358.3906 - val_root_mean_squared_error: 177.0830
# Epoch 33/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29959.3926 - root_mean_squared_error: 173.0878 - val_loss: 31223.7793 - val_root_mean_squared_error: 176.7025
# Epoch 34/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29821.0977 - root_mean_squared_error: 172.6879 - val_loss: 31321.5625 - val_root_mean_squared_error: 176.9790
# Epoch 35/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29918.4863 - root_mean_squared_error: 172.9696 - val_loss: 31152.4902 - val_root_mean_squared_error: 176.5007
# Epoch 36/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29823.5527 - root_mean_squared_error: 172.6950 - val_loss: 31247.9238 - val_root_mean_squared_error: 176.7708
# Epoch 37/100
# 830/830 [==============================] - 3s 3ms/step - loss: 29723.2168 - root_mean_squared_error: 172.4042 - val_loss: 31219.5996 - val_root_mean_squared_error: 176.6907
# Epoch 38/100
# 830/830 [==============================] - 4s 4ms/step - loss: 29749.5391 - root_mean_squared_error: 172.4805 - val_loss: 31206.3906 - val_root_mean_squared_error: 176.6533
# Epoch 39/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29663.4062 - root_mean_squared_error: 172.2307 - val_loss: 31003.3438 - val_root_mean_squared_error: 176.0777
# Epoch 40/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29608.6367 - root_mean_squared_error: 172.0716 - val_loss: 31231.2793 - val_root_mean_squared_error: 176.7237
# Epoch 41/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29619.2051 - root_mean_squared_error: 172.1023 - val_loss: 31423.4238 - val_root_mean_squared_error: 177.2665
# Epoch 42/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29497.8125 - root_mean_squared_error: 171.7493 - val_loss: 31148.1055 - val_root_mean_squared_error: 176.4883
# Epoch 43/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29507.2031 - root_mean_squared_error: 171.7766 - val_loss: 30960.0332 - val_root_mean_squared_error: 175.9546
# Epoch 44/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29503.4121 - root_mean_squared_error: 171.7656 - val_loss: 31070.9219 - val_root_mean_squared_error: 176.2695
# Epoch 45/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29390.5488 - root_mean_squared_error: 171.4367 - val_loss: 31478.0977 - val_root_mean_squared_error: 177.4207
# Epoch 46/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29414.5938 - root_mean_squared_error: 171.5068 - val_loss: 31214.2148 - val_root_mean_squared_error: 176.6754
# Epoch 47/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29347.6055 - root_mean_squared_error: 171.3114 - val_loss: 31410.8008 - val_root_mean_squared_error: 177.2309
# Epoch 48/100
# 830/830 [==============================] - 4s 5ms/step - loss: 29313.8359 - root_mean_squared_error: 171.2128 - val_loss: 31160.9414 - val_root_mean_squared_error: 176.5246
# Epoch 49/100
# 830/830 [==============================] - 4s 4ms/step - loss: 29218.8555 - root_mean_squared_error: 170.9352 - val_loss: 31060.5059 - val_root_mean_squared_error: 176.2399
# Epoch 50/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29218.3633 - root_mean_squared_error: 170.9338 - val_loss: 30883.0547 - val_root_mean_squared_error: 175.7357
# Epoch 51/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29179.1016 - root_mean_squared_error: 170.8189 - val_loss: 31144.7773 - val_root_mean_squared_error: 176.4788
# Epoch 52/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29150.7676 - root_mean_squared_error: 170.7360 - val_loss: 31025.7715 - val_root_mean_squared_error: 176.1413
# Epoch 53/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29095.3105 - root_mean_squared_error: 170.5735 - val_loss: 30937.0410 - val_root_mean_squared_error: 175.8893
# Epoch 54/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29069.9473 - root_mean_squared_error: 170.4991 - val_loss: 31483.2676 - val_root_mean_squared_error: 177.4352
# Epoch 55/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29046.2168 - root_mean_squared_error: 170.4295 - val_loss: 31003.8516 - val_root_mean_squared_error: 176.0791
# Epoch 56/100
# 830/830 [==============================] - 3s 4ms/step - loss: 29083.2754 - root_mean_squared_error: 170.5382 - val_loss: 31179.4141 - val_root_mean_squared_error: 176.5769
# Epoch 57/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28975.8652 - root_mean_squared_error: 170.2230 - val_loss: 31210.4473 - val_root_mean_squared_error: 176.6648
# Epoch 58/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28945.9609 - root_mean_squared_error: 170.1351 - val_loss: 31022.7344 - val_root_mean_squared_error: 176.1327
# Epoch 59/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28964.3730 - root_mean_squared_error: 170.1892 - val_loss: 30814.8398 - val_root_mean_squared_error: 175.5416
# Epoch 60/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28859.2070 - root_mean_squared_error: 169.8800 - val_loss: 30776.3652 - val_root_mean_squared_error: 175.4319
# Epoch 61/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28834.2148 - root_mean_squared_error: 169.8064 - val_loss: 30930.9141 - val_root_mean_squared_error: 175.8719
# Epoch 62/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28777.7500 - root_mean_squared_error: 169.6401 - val_loss: 30829.0176 - val_root_mean_squared_error: 175.5819
# Epoch 63/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28811.6406 - root_mean_squared_error: 169.7399 - val_loss: 30603.4707 - val_root_mean_squared_error: 174.9385
# Epoch 64/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28773.9766 - root_mean_squared_error: 169.6289 - val_loss: 30665.2676 - val_root_mean_squared_error: 175.1150
# Epoch 65/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28703.5762 - root_mean_squared_error: 169.4213 - val_loss: 30700.3691 - val_root_mean_squared_error: 175.2152
# Epoch 66/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28668.9180 - root_mean_squared_error: 169.3190 - val_loss: 30595.3438 - val_root_mean_squared_error: 174.9153
# Epoch 67/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28606.2773 - root_mean_squared_error: 169.1339 - val_loss: 30673.8027 - val_root_mean_squared_error: 175.1394
# Epoch 68/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28666.1973 - root_mean_squared_error: 169.3109 - val_loss: 30810.9258 - val_root_mean_squared_error: 175.5304
# Epoch 69/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28597.2441 - root_mean_squared_error: 169.1072 - val_loss: 30500.5508 - val_root_mean_squared_error: 174.6441
# Epoch 70/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28542.6680 - root_mean_squared_error: 168.9458 - val_loss: 30725.0215 - val_root_mean_squared_error: 175.2855
# Epoch 71/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28582.9805 - root_mean_squared_error: 169.0650 - val_loss: 31289.2109 - val_root_mean_squared_error: 176.8876
# Epoch 72/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28518.5352 - root_mean_squared_error: 168.8743 - val_loss: 30482.5156 - val_root_mean_squared_error: 174.5924
# Epoch 73/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28407.6016 - root_mean_squared_error: 168.5455 - val_loss: 30749.0820 - val_root_mean_squared_error: 175.3542
# Epoch 74/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28374.7910 - root_mean_squared_error: 168.4482 - val_loss: 30660.5098 - val_root_mean_squared_error: 175.1014
# Epoch 75/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28356.2441 - root_mean_squared_error: 168.3931 - val_loss: 30493.8379 - val_root_mean_squared_error: 174.6248
# Epoch 76/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28354.2793 - root_mean_squared_error: 168.3873 - val_loss: 30614.9023 - val_root_mean_squared_error: 174.9711
# Epoch 77/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28388.0977 - root_mean_squared_error: 168.4877 - val_loss: 30735.3086 - val_root_mean_squared_error: 175.3149
# Epoch 78/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28246.3945 - root_mean_squared_error: 168.0666 - val_loss: 30420.2832 - val_root_mean_squared_error: 174.4141
# Epoch 79/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28289.8262 - root_mean_squared_error: 168.1958 - val_loss: 30786.3438 - val_root_mean_squared_error: 175.4604
# Epoch 80/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28286.9473 - root_mean_squared_error: 168.1872 - val_loss: 30510.6016 - val_root_mean_squared_error: 174.6728
# Epoch 81/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28231.7305 - root_mean_squared_error: 168.0230 - val_loss: 30539.0176 - val_root_mean_squared_error: 174.7542
# Epoch 82/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28185.0605 - root_mean_squared_error: 167.8841 - val_loss: 30599.1738 - val_root_mean_squared_error: 174.9262
# Epoch 83/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28177.1719 - root_mean_squared_error: 167.8606 - val_loss: 30557.8848 - val_root_mean_squared_error: 174.8081
# Epoch 84/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28152.7715 - root_mean_squared_error: 167.7879 - val_loss: 30738.9297 - val_root_mean_squared_error: 175.3252
# Epoch 85/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28063.0859 - root_mean_squared_error: 167.5204 - val_loss: 30460.6172 - val_root_mean_squared_error: 174.5297
# Epoch 86/100
# 830/830 [==============================] - 3s 4ms/step - loss: 28143.7109 - root_mean_squared_error: 167.7609 - val_loss: 30468.6113 - val_root_mean_squared_error: 174.5526
# Epoch 87/100
# 490/830 [================>.............] - ETA: 1s - loss: 28177.6074 - root_mean_squared_error: 167.8619
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-02b387917e6c> in <module>()
# ----> 1 model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size = 200, epochs = 100)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
def build_model(optimizer):
  model = Sequential()
  input_layer = X_train.shape[1] / 2
  model.add(Input(shape=(X_train.shape[1],)))
  model.add(Dense(units = input_layer, kernel_initializer = "uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = input_layer, kernel_initializer="uniform", activation = "relu"))
  model.add(Dense(units = 1, kernel_initializer ="uniform"))
  model.compile(loss='mean_squared_error', optimizer=optimizer,  metrics=['RootMeanSquaredError'])
  return model

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense

classifier = KerasRegressor(build_fn = build_model)
parameters = {'batch_size': [10, 50],
              'epochs': [100],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'r2',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_

# %%
grid_search.best_estimator_.model.summary()

# %%
grid_search.best_estimator_.score(X_test, y_test)

# %%
model.summary()

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
from keras import backend as K

def coeff_determination(y_true, y_pred):

    y_true = K.constant(y_true)
    y_pred = K.constant(y_pred)
    
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
y_pred = model.predict(X_train)
coeff_determination(y_train.to_numpy(), y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.7856481>

# %%
y_pred = model.predict(X_test)
coeff_determination(y_test.to_numpy(), y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.76500964>

# %%
import pickle

filename = path + crop + "_Model"

pickle.dump(model, open(filename, "wb"))

model
# Out:
# INFO:tensorflow:Assets written to: ram://bd2b4ec8-a6e2-4d20-a74a-70985e7a0655/assets
# INFO:tensorflow:Assets written to: ram://bd2b4ec8-a6e2-4d20-a74a-70985e7a0655/assets

# %%
filename = path + crop + "_Scaler"

pickle.dump(sc, open(filename, "wb"))

sc
# Out:
# StandardScaler()

# %%
filename = path + crop + "_Df"

pickle.dump(df_save, open(filename, "wb"))

df_save
# Out:
#    Production Of Condition in Kg  Area in Square meter  \
# 0                            0.0                   0.0
#
#    Quantity of indigenous seeds used  Fertilizer Quantity
# 0                                0.0                  0.0

# %%
dfs = [df_region, df_zone, df_district, df_damage, df_irrigated, df_erosion_prevention, df_seed, df_fertilizer, df_fetilizer_type, df_previous]
labels = ["Region", "Zone", "District", "Damage", "Irrigated", "Erosion", "Seed", "Fertilizer", "Fertilizer_Type", "Previous"]

for idx in range(0, len(dfs)):
  df_selected = dfs[idx].iloc[ : 1]

  for col in df_selected.columns:
      df_selected[col].values[:] = 0

  filename = path + crop + "_" + labels[idx]
  pickle.dump(df_selected, open(filename, "wb"))

  print( labels[idx])
# Out:
# Region
# Zone
# District
# Damage
# Irrigated
# Erosion
# Seed
# Fertilizer
# Fertilizer_Type
# Previous
